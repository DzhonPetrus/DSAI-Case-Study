# %% [markdown]
# # Data Preparation
#
# Dataset: <a href="https://www.kaggle.com/vishalmane10/anime-dataset-2022">Anime Dataset 2022</a><br>
# Filename: Anime.csv<br>

# %% [markdown]
# <table>
#   <tr>
#     <th>Feature_Name</th>
#     <th>Feature_Type</th>
#   </tr><tr>
#     <th></th>
#     <th></th>
#   </tr>
# </table>

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
# Set Options for display
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
pd.options.display.float_format = '{:.2f}'.format

#Filter Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
from scipy.stats import norm
from scipy import stats

# %% [markdown]
# ________

# %% [markdown]
# ## Load the Dataset
# * Specify the Parameters (Filepath, Index Column)
# * Check for Date-Time Columns to Parse Dates
# * Check Encoding if file does not load correctly

# %%
df = pd.read_csv("./Anime.csv")

# %% [markdown]
# View the Dataset

# %%
df.head()
# Out:
#    Rank                                               Name  \
# 0     1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1     2                     Fruits Basket the Final Season
# 2     3                                    Mo Dao Zu Shi 3
# 3     4                   Fullmetal Alchemist: Brotherhood
# 4     5                Attack on Titan 3rd Season: Part II
#
#                                      Japanese_name   Type  Episodes  \
# 0                    Kimetsu no Yaiba: Yuukaku-hen  TV          NaN
# 1                          Fruits Basket the Final  TV        13.00
# 2                       The Founder of Diabolism 3  Web       12.00
# 3   Hagane no Renkinjutsushi: Full Metal Alchemist  TV        64.00
# 4             Shingeki no Kyojin Season 3: Part II  TV        10.00
#
#               Studio Release_season  \
# 0           ufotable          Fall
# 1  TMS Entertainment         Spring
# 2   B.C MAY PICTURES            NaN
# 3              Bones         Spring
# 4         WIT Studio         Spring
#
#                                                 Tags  Rating  Release_year  \
# 0  Action, Adventure, Fantasy, Shounen, Demons, H...    4.60       2021.00
# 1  Drama, Fantasy, Romance, Shoujo, Animal Transf...    4.60       2021.00
# 2  Fantasy, Ancient China, Chinese Animation, Cul...    4.58       2021.00
# 3  Action, Adventure, Drama, Fantasy, Mystery, Sh...    4.58       2009.00
# 4  Action, Fantasy, Horror, Shounen, Dark Fantasy...    4.57       2019.00
#
#    End_year                                        Description  \
# 0       NaN  'Tanjiro and his friends accompany the Hashira...
# 1       NaN                  'The final arc of Fruits Basket.'
# 2       NaN               'The third season of Mo Dao Zu Shi.'
# 3   2010.00  "The foundation of alchemy is based on the law...
# 4       NaN  'The battle to retake Wall Maria begins now! W...
#
#                                      Content_Warning  \
# 0                                  Explicit Violence
# 1  Emotional Abuse,, Mature Themes,, Physical Abu...
# 2                                                NaN
# 3  Animal Abuse,, Mature Themes,, Violence,, Dome...
# 4                    Cannibalism,, Explicit Violence
#
#                                        Related_Mange  \
# 0                     Demon Slayer: Kimetsu no Yaiba
# 1               Fruits Basket, Fruits Basket Another
# 2  Grandmaster of Demonic Cultivation: Mo Dao Zu ...
# 3  Fullmetal Alchemist, Fullmetal Alchemist (Ligh...
# 4  Attack on Titan, Attack on Titan: End of the W...
#
#                                        Related_anime  \
# 0  Demon Slayer: Kimetsu no Yaiba, Demon Slayer: ...
# 1  Fruits Basket 1st Season, Fruits Basket 2nd Se...
# 2                   Mo Dao Zu Shi 2, Mo Dao Zu Shi Q
# 3  Fullmetal Alchemist: Brotherhood Specials, Ful...
# 4  Attack on Titan, Attack on Titan 2nd Season, A...
#
#                                         Voice_actors  \
# 0  Inosuke Hashibira : Yoshitsugu Matsuoka, Nezuk...
# 1  Akito Sohma : Maaya Sakamoto, Kyo Sohma : Yuum...
# 2  Lan Wangji, Wei Wuxian, Jiang Cheng, Jin Guang...
# 3  Alphonse Elric : Rie Kugimiya, Edward Elric : ...
# 4  Armin Arlelt : Marina Inoue, Eren Jaeger : Yuu...
#
#                                                staff
# 0  Koyoharu Gotouge : Original Creator, Haruo Sot...
# 1  Natsuki Takaya : Original Creator, Yoshihide I...
# 2  Mo Xiang Tong Xiu : Original Creator, Xiong Ke...
# 3  Hiromu Arakawa : Original Creator, Yasuhiro Ir...
# 4  Hajime Isayama : Original Creator, Tetsurou Ar...

# %% [markdown]
# Check the Shape

# %%
df.shape
# Out:
# (18495, 17)

# %% [markdown]
# ## Ensure Columns / Features have Proper Labels

# %% [markdown]
# Remove any columns that have not been labelled properly or are of unknown feature type

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Japanese_name', 'Type', 'Episodes', 'Studio',
#        'Release_season', 'Tags', 'Rating', 'Release_year', 'End_year',
#        'Description', 'Content_Warning', 'Related_Mange', 'Related_anime',
#        'Voice_actors', 'staff'],
#       dtype='object')

# %% [markdown]
# ## Ensure Correct Format of Values

# %% [markdown]
# Use the table above as reference

# %%
df.dtypes
# Out:
# Rank                 int64
# Name                object
# Japanese_name       object
# Type                object
# Episodes           float64
# Studio              object
# Release_season      object
# Tags                object
# Rating             float64
# Release_year       float64
# End_year           float64
# Description         object
# Content_Warning     object
# Related_Mange       object
# Related_anime       object
# Voice_actors        object
# staff               object
# dtype: object

# %% [markdown]
# ## Remove Duplicates

# %% [markdown]
# Check if there are duplicated rows

# %%
df.index.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Remove the duplicates if any

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Japanese_name, Type, Episodes, Studio, Release_season, Tags, Rating, Release_year, End_year, Description, Content_Warning, Related_Mange, Related_anime, Voice_actors, staff]
# Index: []

# %% [markdown]
# Check if the rows are dropped

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## Handle Missing Data

# %%
df.head()
# Out:
#    Rank                                               Name  \
# 0     1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1     2                     Fruits Basket the Final Season
# 2     3                                    Mo Dao Zu Shi 3
# 3     4                   Fullmetal Alchemist: Brotherhood
# 4     5                Attack on Titan 3rd Season: Part II
#
#                                      Japanese_name   Type  Episodes  \
# 0                    Kimetsu no Yaiba: Yuukaku-hen  TV          NaN
# 1                          Fruits Basket the Final  TV        13.00
# 2                       The Founder of Diabolism 3  Web       12.00
# 3   Hagane no Renkinjutsushi: Full Metal Alchemist  TV        64.00
# 4             Shingeki no Kyojin Season 3: Part II  TV        10.00
#
#               Studio Release_season  \
# 0           ufotable          Fall
# 1  TMS Entertainment         Spring
# 2   B.C MAY PICTURES            NaN
# 3              Bones         Spring
# 4         WIT Studio         Spring
#
#                                                 Tags  Rating  Release_year  \
# 0  Action, Adventure, Fantasy, Shounen, Demons, H...    4.60       2021.00
# 1  Drama, Fantasy, Romance, Shoujo, Animal Transf...    4.60       2021.00
# 2  Fantasy, Ancient China, Chinese Animation, Cul...    4.58       2021.00
# 3  Action, Adventure, Drama, Fantasy, Mystery, Sh...    4.58       2009.00
# 4  Action, Fantasy, Horror, Shounen, Dark Fantasy...    4.57       2019.00
#
#    End_year                                        Description  \
# 0       NaN  'Tanjiro and his friends accompany the Hashira...
# 1       NaN                  'The final arc of Fruits Basket.'
# 2       NaN               'The third season of Mo Dao Zu Shi.'
# 3   2010.00  "The foundation of alchemy is based on the law...
# 4       NaN  'The battle to retake Wall Maria begins now! W...
#
#                                      Content_Warning  \
# 0                                  Explicit Violence
# 1  Emotional Abuse,, Mature Themes,, Physical Abu...
# 2                                                NaN
# 3  Animal Abuse,, Mature Themes,, Violence,, Dome...
# 4                    Cannibalism,, Explicit Violence
#
#                                        Related_Mange  \
# 0                     Demon Slayer: Kimetsu no Yaiba
# 1               Fruits Basket, Fruits Basket Another
# 2  Grandmaster of Demonic Cultivation: Mo Dao Zu ...
# 3  Fullmetal Alchemist, Fullmetal Alchemist (Ligh...
# 4  Attack on Titan, Attack on Titan: End of the W...
#
#                                        Related_anime  \
# 0  Demon Slayer: Kimetsu no Yaiba, Demon Slayer: ...
# 1  Fruits Basket 1st Season, Fruits Basket 2nd Se...
# 2                   Mo Dao Zu Shi 2, Mo Dao Zu Shi Q
# 3  Fullmetal Alchemist: Brotherhood Specials, Ful...
# 4  Attack on Titan, Attack on Titan 2nd Season, A...
#
#                                         Voice_actors  \
# 0  Inosuke Hashibira : Yoshitsugu Matsuoka, Nezuk...
# 1  Akito Sohma : Maaya Sakamoto, Kyo Sohma : Yuum...
# 2  Lan Wangji, Wei Wuxian, Jiang Cheng, Jin Guang...
# 3  Alphonse Elric : Rie Kugimiya, Edward Elric : ...
# 4  Armin Arlelt : Marina Inoue, Eren Jaeger : Yuu...
#
#                                                staff
# 0  Koyoharu Gotouge : Original Creator, Haruo Sot...
# 1  Natsuki Takaya : Original Creator, Yoshihide I...
# 2  Mo Xiang Tong Xiu : Original Creator, Xiong Ke...
# 3  Hiromu Arakawa : Original Creator, Yasuhiro Ir...
# 4  Hajime Isayama : Original Creator, Tetsurou Ar...

# %%
#Gets the total number of missing data
total = df.isnull().sum().sort_values(ascending=False)

# %%
#Get % of Null
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)

# %%
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_data.head(20)
# Out:
#                  Total  Percent
# Content_Warning  16655     0.90
# End_year         15641     0.85
# Release_season   14379     0.78
# Related_Mange    10868     0.59
# Japanese_name    10557     0.57
# Episodes          8994     0.49
# Related_anime     8432     0.46
# Studio            6477     0.35
# staff             5490     0.30
# Voice_actors      3186     0.17
# Rating            3131     0.17
# Tags               400     0.02
# Release_year       383     0.02
# Description          4     0.00
# Name                 0     0.00
# Type                 0     0.00
# Rank                 0     0.00

# %%
df.fillna({'Content_Warning' : 'N/A'}, inplace=True)

#missing data will fill them up 0 because its int
df.fillna({'End_year' : '0'}, inplace=True)

df.fillna({'Release_season' : 'N/A'}, inplace=True)

df.fillna({'Related_Mange' : 'N/A'}, inplace=True)

df.fillna({'Japanese_name' : 'N/A'}, inplace=True)

#maybe ongoing but we will fillin first by 0 episode
df.fillna({'Episodes' : '0'}, inplace=True)

df.fillna({'Related_anime' : 'N/A'}, inplace=True)

df.fillna({'Studio' : 'N/A'} , inplace=True)

df.fillna({'staff' : 'N/A'}, inplace=True)

df.fillna({'Voice_actors' : 'N/A'}, inplace=True)

#just fill in 0
df.fillna({'Rating' : '0'}, inplace=True)

df.fillna({'Tags' : 'N/A'}, inplace=True)

df.fillna({'Release_year' : '0'}, inplace=True)

df
# Out:
#         Rank                                               Name  \
# 0          1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1          2                     Fruits Basket the Final Season
# 2          3                                    Mo Dao Zu Shi 3
# 3          4                   Fullmetal Alchemist: Brotherhood
# 4          5                Attack on Titan 3rd Season: Part II
# ...      ...                                                ...
# 18490  18491  Qin Shi Mingyue: Canghai Hengliu Xiaomeng Spec...
# 18491  18492                      Yi Tang Juchang: Sanguo Yanyi
# 18492  18493          Fenghuang Ji Xiang Yu Qingming Shanghe Tu
# 18493  18494                      Chengshi Jiyi Wo Men de Jieri
# 18494  18495  Heisei Inu Monogatari Bow: Genshi Inu Monogata...
#
#                                          Japanese_name   Type Episodes  \
# 0                        Kimetsu no Yaiba: Yuukaku-hen  TV           0
# 1                              Fruits Basket the Final  TV       13.00
# 2                           The Founder of Diabolism 3  Web      12.00
# 3       Hagane no Renkinjutsushi: Full Metal Alchemist  TV       64.00
# 4                 Shingeki no Kyojin Season 3: Part II  TV       10.00
# ...                                                ...    ...      ...
# 18490                                              N/A  Web       2.00
# 18491                                              N/A  TV      108.00
# 18492                                              N/A  TV       13.00
# 18493                                              N/A  TV           0
# 18494                                              N/A  Movie        0
#
#                              Studio Release_season  \
# 0                          ufotable          Fall
# 1                 TMS Entertainment         Spring
# 2                  B.C MAY PICTURES            N/A
# 3                             Bones         Spring
# 4                        WIT Studio         Spring
# ...                             ...            ...
# 18490  Sparkly Key Animation Studio            N/A
# 18491                           N/A            N/A
# 18492                           N/A            N/A
# 18493                           N/A            N/A
# 18494              Nippon Animation            N/A
#
#                                                     Tags Rating Release_year  \
# 0      Action, Adventure, Fantasy, Shounen, Demons, H...   4.60      2021.00
# 1      Drama, Fantasy, Romance, Shoujo, Animal Transf...   4.60      2021.00
# 2      Fantasy, Ancient China, Chinese Animation, Cul...   4.58      2021.00
# 3      Action, Adventure, Drama, Fantasy, Mystery, Sh...   4.58      2009.00
# 4      Action, Fantasy, Horror, Shounen, Dark Fantasy...   4.57      2019.00
# ...                                                  ...    ...          ...
# 18490  Action, Ancient China, Chinese Animation, Hist...      0      2020.00
# 18491                                  Chinese Animation      0      2010.00
# 18492  Chinese Animation, Family Friendly, Short Epis...      0      2020.00
# 18493  Chinese Animation, Family Friendly, Short Epis...      0      2020.00
# 18494                        Comedy, Slice of Life, Dogs      0      1994.00
#
#       End_year                                        Description  \
# 0            0  'Tanjiro and his friends accompany the Hashira...
# 1            0                  'The final arc of Fruits Basket.'
# 2            0               'The third season of Mo Dao Zu Shi.'
# 3      2010.00  "The foundation of alchemy is based on the law...
# 4            0  'The battle to retake Wall Maria begins now! W...
# ...        ...                                                ...
# 18490        0  Special episodes of Qin Shi Mingyue: Canghai H...
# 18491        0                 No synopsis yet - check back soon!
# 18492        0                 No synopsis yet - check back soon!
# 18493        0                 No synopsis yet - check back soon!
# 18494        0                 No synopsis yet - check back soon!
#
#                                          Content_Warning  \
# 0                                      Explicit Violence
# 1      Emotional Abuse,, Mature Themes,, Physical Abu...
# 2                                                    N/A
# 3      Animal Abuse,, Mature Themes,, Violence,, Dome...
# 4                        Cannibalism,, Explicit Violence
# ...                                                  ...
# 18490                                                N/A
# 18491                                                N/A
# 18492                                                N/A
# 18493                                                N/A
# 18494                                                N/A
#
#                                            Related_Mange  \
# 0                         Demon Slayer: Kimetsu no Yaiba
# 1                   Fruits Basket, Fruits Basket Another
# 2      Grandmaster of Demonic Cultivation: Mo Dao Zu ...
# 3      Fullmetal Alchemist, Fullmetal Alchemist (Ligh...
# 4      Attack on Titan, Attack on Titan: End of the W...
# ...                                                  ...
# 18490                                                N/A
# 18491                                                N/A
# 18492                                                N/A
# 18493                                                N/A
# 18494                                                N/A
#
#                                            Related_anime  \
# 0      Demon Slayer: Kimetsu no Yaiba, Demon Slayer: ...
# 1      Fruits Basket 1st Season, Fruits Basket 2nd Se...
# 2                       Mo Dao Zu Shi 2, Mo Dao Zu Shi Q
# 3      Fullmetal Alchemist: Brotherhood Specials, Ful...
# 4      Attack on Titan, Attack on Titan 2nd Season, A...
# ...                                                  ...
# 18490                   Qin Shi Mingyue: Canghai Hengliu
# 18491                                                N/A
# 18492                                                N/A
# 18493                                                N/A
# 18494                          Heisei Inu Monogatari Bow
#
#                                             Voice_actors  \
# 0      Inosuke Hashibira : Yoshitsugu Matsuoka, Nezuk...
# 1      Akito Sohma : Maaya Sakamoto, Kyo Sohma : Yuum...
# 2      Lan Wangji, Wei Wuxian, Jiang Cheng, Jin Guang...
# 3      Alphonse Elric : Rie Kugimiya, Edward Elric : ...
# 4      Armin Arlelt : Marina Inoue, Eren Jaeger : Yuu...
# ...                                                  ...
# 18490                                                N/A
# 18491                                                N/A
# 18492                                                N/A
# 18493                                                N/A
# 18494                                                N/A
#
#                                                    staff
# 0      Koyoharu Gotouge : Original Creator, Haruo Sot...
# 1      Natsuki Takaya : Original Creator, Yoshihide I...
# 2      Mo Xiang Tong Xiu : Original Creator, Xiong Ke...
# 3      Hiromu Arakawa : Original Creator, Yasuhiro Ir...
# 4      Hajime Isayama : Original Creator, Tetsurou Ar...
# ...                                                  ...
# 18490                                                N/A
# 18491                                                N/A
# 18492                                                N/A
# 18493                                                N/A
# 18494                                                N/A
#
# [18495 rows x 17 columns]

# %% [markdown]
# ______

# %% [markdown]
# # Save the final dataset as a CSV File

# %%
df.to_csv('./Anime_prepped.csv')

# %% [markdown]
# ### Check if it loads correctly

# %%
df_check = pd.read_csv('./Anime_prepped.csv', index_col='Unnamed: 0')

# %%
df_check.tail()
# Out:
#         Rank                                               Name Japanese_name  \
# 18490  18491  Qin Shi Mingyue: Canghai Hengliu Xiaomeng Spec...           NaN
# 18491  18492                      Yi Tang Juchang: Sanguo Yanyi           NaN
# 18492  18493          Fenghuang Ji Xiang Yu Qingming Shanghe Tu           NaN
# 18493  18494                      Chengshi Jiyi Wo Men de Jieri           NaN
# 18494  18495  Heisei Inu Monogatari Bow: Genshi Inu Monogata...           NaN
#
#         Type  Episodes                        Studio Release_season  \
# 18490  Web        2.00  Sparkly Key Animation Studio            NaN
# 18491  TV       108.00                           NaN            NaN
# 18492  TV        13.00                           NaN            NaN
# 18493  TV         0.00                           NaN            NaN
# 18494  Movie      0.00              Nippon Animation            NaN
#
#                                                     Tags  Rating  \
# 18490  Action, Ancient China, Chinese Animation, Hist...    0.00
# 18491                                  Chinese Animation    0.00
# 18492  Chinese Animation, Family Friendly, Short Epis...    0.00
# 18493  Chinese Animation, Family Friendly, Short Epis...    0.00
# 18494                        Comedy, Slice of Life, Dogs    0.00
#
#        Release_year  End_year  \
# 18490       2020.00      0.00
# 18491       2010.00      0.00
# 18492       2020.00      0.00
# 18493       2020.00      0.00
# 18494       1994.00      0.00
#
#                                              Description Content_Warning  \
# 18490  Special episodes of Qin Shi Mingyue: Canghai H...             NaN
# 18491                 No synopsis yet - check back soon!             NaN
# 18492                 No synopsis yet - check back soon!             NaN
# 18493                 No synopsis yet - check back soon!             NaN
# 18494                 No synopsis yet - check back soon!             NaN
#
#       Related_Mange                     Related_anime Voice_actors staff
# 18490           NaN  Qin Shi Mingyue: Canghai Hengliu          NaN   NaN
# 18491           NaN                               NaN          NaN   NaN
# 18492           NaN                               NaN          NaN   NaN
# 18493           NaN                               NaN          NaN   NaN
# 18494           NaN         Heisei Inu Monogatari Bow          NaN   NaN
